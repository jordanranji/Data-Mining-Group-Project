# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/ClutchPlayerData.csv")

sums = df.groupby("player_id")[["FGM", "FGA", "FGA depth"]].sum()
df = df.groupby("player_id")[["FGM", "FGA", "FGA depth"]].mean()

sums = sums.loc[sums.FGA > 125]

df = df.loc[df.index.isin(sums.index)]

# %%
df.plot.scatter(x='FGM', y='FGA', s="FGA depth")
# Out:
# <Axes: xlabel='FGM', ylabel='FGA'>

# %%
df["fg%"] = np.where(df["FGA"] > 0, df["FGM"] / df["FGA"], 0)
# df.sort_values(by="FGA depth", ascending=True)
